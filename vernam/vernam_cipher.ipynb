# %%
import random
import time
import itertools

#функция для чтения из файла
def readFile(name):
    file=open(name)
    text = file.read()
    file.close()
    return text

#функция для запись в файл вектора
def writeFile(text, name):
    file=open(name, 'w')
    file.write(text)
    file.close()

  
def encrypt(str, key):
  encrypt_text =[]
  if len(str)==len(key):
    for(symbol_str, symbol_key) in zip(str, key):
      encrypt_text.append(chr(ord(symbol_str)^ord(symbol_key)))
  return " ".join(encrypt_text)

def decrypt(str, key):
  decrypt_text =[]
  if len(str)==len(key):
    for(symbol_str, symbol_key) in zip(str, key):
      print(ord(symbol_str)^ord(symbol_key))
      decrypt_text.append(chr(ord(symbol_str)^ord(symbol_key)))
  return " ".join(decrypt_text)


def generate_key(lenstr):
  key = ''
  for i in range(lenstr):
      key = key + chr(random.randrange(256))
  return " ".join(key)


def count_keys_len(length):
    counted_keys = 0
    for _ in range(256 ** length):
        counted_keys += 1
    print(counted_keys)
    return counted_keys


def search_key():
  length=1
  #run_task = True
  print('Перебор ключей, число вариантов, время')
  while True:
      start = time.perf_counter()
      key_counter = count_keys_len(length)
      stop = time.perf_counter()
      print('Длина ключа: ' + str(length) + ' ; число вариантов: '
              +str(key_counter) + ' ; время перебора:' + str(stop - start))
      if stop - start > 600:
        break
      length += 1


def search_key_text(str, enstr):
  key=[];
  for(symbol_str, symbol_enstr) in zip(str, enstr):
      key.append(chr(ord(symbol_str)^ord(symbol_enstr)))
  return " ".join(key)



text = 'EVTIQWXQVV'
key = 'ALLSWELLTH'
en = encrypt(text, key)
print(en)
#deck = decrypt(en, key)
#print(deck)



rand = generate_key(len(text))
print(rand)
#search_key()

key = 'ALLSWELLTHJGHHGVVGFTDNHTFCHGNB KN_ CFGDEGFZ$&BGCG*'
text1 = readFile('/content/drive/MyDrive/pyth/textpath/text1.txt')
enstr1= encrypt(text1, key)
writeFile(enstr1, '/content/drive/MyDrive/pyth/textpath/keytext1.txt')

key = 'ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG%EGNVDCJFHVZ$UBGCG*'
text2 = readFile('/content/drive/MyDrive/pyth/textpath/text2.txt')
enstr2= encrypt(text2, key)
writeFile(enstr2, '/content/drive/MyDrive/pyth/textpath/keytext2.txt')


key = 'ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**'
text3 = readFile('/content/drive/MyDrive/pyth/textpath/text3.txt')
enstr3= encrypt(text3, key)
writeFile(enstr3, '/content/drive/MyDrive/pyth/textpath/keytext3.txt')


key = 'ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVBALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**N_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**'
text4 = readFile('/content/drive/MyDrive/pyth/textpath/text4.txt')
enstr4= encrypt(text4, key)
writeFile(enstr4, '/content/drive/MyDrive/pyth/textpath/keytext4.txt')

key = 'ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVBALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**N_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b ALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVBALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKALLGVSW^E$L&L*TRHJGHFALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEGNVDCJFHVZ$#BGCG*HHGTC VVG__FTDN_HT--KSEBALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*JFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGTEGNVDCJFHVZ$BGCG*AALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**N_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**--KGSKN_- +b CFfdEVKLGBEGKEGNVDCJFHVZ$#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**#BGCG*GHBJLLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**VG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGEEGNVDCJFHVZ$BGCG*ALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEGOEGNVDCJFHVZ$#BGCG*HNGCGNVB--KGSKN_- +b CFfdEVKLGBEGSEGNALLGVSW^E$L&L*TRHJGHFHHGTC VVALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG_EGNVDCJFHVZ$#BGCG*G__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CALLGVSW^E$L&L*TRHJGHFHHGTC VVG__FTDN_HT--KSEBJFCHNGCGNVB--KGSKN_- +b CFfdEVKLGBEG=EGNVDCJFHVZ$BGCG*FfdEVKLGBEG^EGNVDCJFHVZ$#BGCG*VDCJFHVZ$BGCG**'
text5 = readFile('/content/drive/MyDrive/pyth/textpath/text5.txt')
enstr5= encrypt(text5, key)
writeFile(enstr5, '/content/drive/MyDrive/pyth/textpath/keytext5.txt')

for i in range(1, 6):
  text = readFile(f'/content/drive/MyDrive/pyth/textpath/text{i}.txt')
  entext = readFile(f'/content/drive/MyDrive/pyth/textpath/keytext{i}.txt')
  start = time.perf_counter()
  keytext = search_key_text(text, entext)
  stop = time.perf_counter()
  print(f'Время на ключ: {stop-start}\n')
  start = time.perf_counter()
  enctext = encrypt(text, keytext)
  stop = time.perf_counter()
  print(f'Время на шифрование: {stop-start}\n')
  start = time.perf_counter()
  dectext = decrypt(enctext, keytext)
  stop = time.perf_counter()
  print(f'Время на дешифрование: {stop-start}\n')



def search_option(leters, c1c2):
  i=0
  ls =[]
  t =[]
  for j in c1c2:
    #print(ord(j))
    i=0
    lsm=[]
    while i <= len(leters)-1:
      #print(leters[i])
      if((chr(ord(leters[i][0])^ord(leters[i][1])))==j):
          #print(leters[i])
          lsm.append(leters[i])
          
      i+=1
    #print(lsm) 
    t.append(lsm)
  #print(t) 
  return t


"""

textm1 = 'EVTIQWXQVV'
textm2 = 'GKLODESHKH'

key = 'ALLSWELLTH'

en1 = encrypt(textm1, key)
print(en1)
#writeFile(en1, '/content/drive/MyDrive/pyth/textpath/m1.txt')
en2 = encrypt(textm2, key)
print(en2)
#writeFile(en2, '/content/drive/MyDrive/pyth/textpath/m2.txt')
c1c2 = encrypt(en1, en2)
print(c1c2)

en3 = encrypt(textm3, key)
print(en3)
c1c2c3 = encrypt(c1c2, en3)
print(c1c2c3)
en4 = encrypt(textm3, key)
print(en4)
c1c2c3c4 = encrypt(c1c2c3, en4)
print(c1c2c3c4)

a = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
b = list(itertools.combinations(a, 2))
#print(len(b))
n =search_option(b, c1c2)
#print(n)

#b = list(itertools.combinations(a, 4))
#n =search_option(b, c1c2c3c4)
#print(n)

#пример текста
m1='EVT'
m2='GKL'
encr1 = en1[:3]
print(encr1)
encr2 = en2[:3]
print(encr2)

keys1= search_key_text(m1, encr1)
print(keys1)
keys2= search_key_text(m2, encr2)
print(keys2)

"""
# Out:
#
# [ [
#  Ì õ Þ L ÷ ú h
# Время на ключ: 5.5916999826877145e-05
#
# Время на шифрование: 4.220999926474178e-06
#
# Время на дешифрование: 1.8239998098579235e-06
#
# Время на ключ: 0.00010371300004408113
#
# Время на шифрование: 3.83099995815428e-06
#
# Время на дешифрование: 2.7520000003278255e-06
#
# Время на ключ: 7.532000381615944e-06
#
# Время на шифрование: 4.065999746671878e-06
#
# Время на дешифрование: 4.632000127458014e-06
#
# Время на ключ: 6.3640000007580966e-06
#
# Время на шифрование: 4.012999852420762e-06
#
# Время на дешифрование: 4.285000159143237e-06
#
# Время на ключ: 6.728000244038412e-06
#
# Время на шифрование: 3.858999662043061e-06
#
# Время на дешифрование: 4.60599994767108e-06
# ...
